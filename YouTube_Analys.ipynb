# %%
# pull in the raw data
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

df_ca = pd.read_csv('youtube-new/CAvideos.csv')
df_de = pd.read_csv('youtube-new/DEvideos.csv')
df_fr = pd.read_csv('youtube-new/FRvideos.csv')
df_gb = pd.read_csv('youtube-new/GBvideos.csv')
df_in = pd.read_csv('youtube-new/INvideos.csv')
#df_jp = pd.read_csv('youtube-new/JPvideos.csv')
#df_kr = pd.read_csv('youtube-new/KRvideos.csv')
#df_mx = pd.read_csv('youtube-new/MXvideos.csv')
#df_ru = pd.read_csv('youtube-new/RUvideos.csv')
df_us = pd.read_csv('youtube-new/USvideos.csv')

df_us.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40949 entries, 0 to 40948
# Data columns (total 16 columns):
# video_id                  40949 non-null object
# trending_date             40949 non-null object
# title                     40949 non-null object
# channel_title             40949 non-null object
# category_id               40949 non-null int64
# publish_time              40949 non-null object
# tags                      40949 non-null object
# views                     40949 non-null int64
# likes                     40949 non-null int64
# dislikes                  40949 non-null int64
# comment_count             40949 non-null int64
# thumbnail_link            40949 non-null object
# comments_disabled         40949 non-null bool
# ratings_disabled          40949 non-null bool
# video_error_or_removed    40949 non-null bool
# description               40379 non-null object
# dtypes: bool(3), int64(5), object(8)
# memory usage: 4.2+ MB

# %%
# add the country code to the tables before merging them
df_ca['country'] = 'ca'
df_de['country'] = 'de'
df_fr['country'] = 'fr'
df_gb['country'] = 'gb'
df_in['country'] = 'in'
df_us['country'] = 'us'

df_us['country'].head()
# Out:
# 0    us
# 1    us
# 2    us
# 3    us
# 4    us
# Name: country, dtype: object

# %%
# concatinate the dataframes into one giant dataframe
frames = [df_ca, df_de, df_fr, df_gb, df_in, df_us]

df_master = pd.concat(frames)
df_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 239662 entries, 0 to 40948
# Data columns (total 17 columns):
# video_id                  239662 non-null object
# trending_date             239662 non-null object
# title                     239662 non-null object
# channel_title             239662 non-null object
# category_id               239662 non-null int64
# publish_time              239662 non-null object
# tags                      239662 non-null object
# views                     239662 non-null int64
# likes                     239662 non-null int64
# dislikes                  239662 non-null int64
# comment_count             239662 non-null int64
# thumbnail_link            239662 non-null object
# comments_disabled         239662 non-null bool
# ratings_disabled          239662 non-null bool
# video_error_or_removed    239662 non-null bool
# description               232159 non-null object
# country                   239662 non-null object
# ...

# %%
df_master.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# ...
